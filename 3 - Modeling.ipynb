# %% [markdown]
# ## MODELING

# %%
# !ls dataset
# Out:
# Data  Data.zip	prova.csv

# %%
import pandas
from apyori import apriori

# %%
df = pandas.read_csv("./dataset/prova.csv", sep="\t")
df.drop(["Attempt"],axis=1)[:3]
# Out:
#        Unnamed: 0        BLOCKID10                            First_POI  \
# 0               0  371190032011003            CHARLOTTE WOOD APARTMENTS
# 1              12  371190015041006            UNITED TREATMENT FACILITY
# 2              15  371190001001020                               hotels
# 3              17  371190019113000           INTERACTIVE COMMUNICATIONS
# 4              18  371190051001003                  CHARLOTTE MANOR LLC
# 5              22  371190042003001          ENDERLY PARK RECREATION CTR
# 6              23  371190005003013                     GREENS LUNCH INC
# 7              27  371190038023020                     FITNESS TOGETHER
# 8              29  371190001001020                   COYOTE UGLY SALOON
# 9              31  371190013001011       WEESIES HOME CARE SERVICES INC
# 10             35  371190006002032                CASSIE'S CLEANING SVC
# 11             46  371190001001020                   COYOTE UGLY SALOON
# ...

# %%
crimes = []
for i, row in df.iterrows():
    crimes.append(row.tolist())

# %%
gino = list(apriori(crimes, min_support=0.3, min_confidence=0.1))
len(gino)
# Out:
# 19

# %%
# %% time
#
# from pymining import itemmining, assocrules, perftesting
# transactions = perftesting.get_default_transactions()
#
#
# relim_input = itemmining.get_relim_input(crimes)
# item_sets = itemmining.relim(relim_input, min_support=2)
# rules = assocrules.mine_assoc_rules(item_sets, min_support=2, min_confidence=0.5)
# rules
